# %%
import pandas as pd

# %% [markdown]
# -------------------

# %% [markdown]
# # Fazendo o processo de ETL no python

# %%
df = pd.read_excel("DADOS\\brasileirao.xlsx")

# %%
lista = df['Club'].unique()

# %%
clubes_ordenados = sorted(lista)

# %%
clubes_ordenados
# Out:
# ['América Mineiro',
#  'América-RN',
#  'Athletico Paranaense',
#  'Atlético Goianiense',
#  'Atlético Mineiro',
#  'Atlético Paranaense',
#  'Avaí',
#  'Bahia',
#  'Barueri',
#  'Botafogo',
#  'Bragantino',
#  'Brasiliense',
#  'CSA',
#  'Ceará',
#  'Chapecoense',
#  'Corinthians',
#  'Coritiba',
#  'Criciúma',
#  'Cruzeiro',
#  'Cuiabá',
#  'Figueirense',
#  'Flamengo',
#  'Fluminense',
#  'Fortaleza',
#  'Goiás',
#  'Grêmio',
#  'Grêmio Prudente',
#  'Guarani',
#  'Internacional',
#  'Ipatinga',
#  'Joinville',
#  'Juventude',
#  'Náutico',
#  'Palmeiras',
#  'Paraná',
#  'Paysandu',
#  'Ponte Preta',
#  'Portuguesa',
#  'Santa Cruz',
#  'Santo André',
#  'Santos',
#  'Sport',
#  'São Caetano',
#  'São Paulo',
#  'Vasco',
#  'Vasco da Gama',
#  'Vitória']

# %%
mappings = {'América-MG': 'América Mineiro', '\xa0Santos': 'Santos'}
df['Club'] = df['Club'].replace(mappings)

# %%
lista = df['Club'].unique()

# %%
df.to_excel("DADOS\\Brasileirao.xlsx",index=False)

# %% [markdown]
# ---------------

# %%
df1 = pd.read_excel("DADOS\\brasileirao_serie_a.xlsx")

# %%
df1.head()
# Out:
#    ano_campeonato       data  rodada          estadio arbitro  publico  \
# 0            2003 2003-05-11       8  Arena do Grêmio     NaN      NaN
# 1            2003 2003-06-15      13  Arena do Grêmio     NaN      NaN
# 2            2003 2003-07-06      16  Arena do Grêmio     NaN      NaN
# 3            2003 2003-08-02      23  Arena do Grêmio     NaN      NaN
# 4            2003 2003-08-23      28  Arena do Grêmio     NaN      NaN
#
#    publico_max time_mandante time_visitante tecnico_mandante  ...  \
# 0          NaN        Grêmio    Coritiba FC              NaN  ...
# 1          NaN        Grêmio  Internacional              NaN  ...
# 2          NaN        Grêmio       Flamengo              NaN  ...
# 3          NaN        Grêmio      Santos FC              NaN  ...
# 4          NaN        Grêmio    São Caetano              NaN  ...
#
#   chutes_bola_parada_mandante  chutes_bola_parada_visitante  defesas_mandante  \
# ...

# %%
lista1 = df1['time_mandante'].unique()

# %%
lista1 = sorted(lista1)

# %%
lista1
# Out:
# ['América Mineiro',
#  'América-RN',
#  'Athletico Paranaense',
#  'Atlético Goianiense',
#  'Atlético Mineiro',
#  'Atlético Paranaense',
#  'Avaí',
#  'Bahia',
#  'Barueri',
#  'Botafogo',
#  'Bragantino',
#  'Brasiliense',
#  'CSA',
#  'Ceará',
#  'Chapecoense',
#  'Corinthians',
#  'Coritiba',
#  'Criciúma',
#  'Cruzeiro',
#  'Cuiabá',
#  'Figueirense',
#  'Flamengo',
#  'Fluminense',
#  'Fortaleza',
#  'Goiás',
#  'Grêmio',
#  'Guarani',
#  'Internacional',
#  'Ipatinga',
#  'Joinville',
#  'Juventude',
#  'Náutico',
#  'Palmeiras',
#  'Paraná',
#  'Paysandu',
#  'Ponte Preta',
#  'Portuguesa',
#  'Santa Cruz',
#  'Santo André',
#  'Santos',
#  'Sport',
#  'São Caetano',
#  'São Paulo',
#  'Vasco da Gama',
#  'Vitória']

# %%
mappings = {'América-MG' : 'América Mineiro',
 'Athletico-PR': 'Athletico Paranaense',
 'Atlético-GO': 'Atlético Goianiense',
 'Atlético-MG': 'Atlético Mineiro',
 'Atlético-PR': 'Atlético Paranaense',
 'AvaÃ\xad FC': 'Avaí',
 'Brasiliense-DF' : 'Brasiliense',
 'Ceará SC' : 'Ceará',
 'Coritiba FC' : 'Coritiba',
 'Criciúma EC' : 'Criciúma',
 'Cuiabá-MT' : 'Cuiabá',
 'EC Bahia' :'Bahia',
 'EC Vitória': 'Vitória',
 'Figueirense FC': 'Figueirense',
 'Goiás EC' :'Goiás',
 'Ipatinga FC' : 'Ipatinga',
 'Joinville-SC' : 'Joinville',
 'Paysandu SC' : 'Paysandu',
 'RB Bragantino' : 'Bragantino',
 'Santos FC' : 'Santos',
 'Sport Recife' : 'Sport',
 }
df1['time_mandante'] = df1['time_mandante'].replace(mappings)
df1['time_visitante'] = df1['time_visitante'].replace(mappings)

# %%
df1.to_excel("DADOS\\brasileirao_serie_a.xlsx",index=False)

# %% [markdown]
# ----------

# %%
df2 = pd.read_csv("DADOS\\campeonato-brasileiro-cartoes.csv")
df2.head()
# Out:
#    partida_id  rodata          clube   cartao                      atleta  \
# 0        4607       1    Figueirense  Amarelo      Paulo Roberto da Silva
# 1        4608       1  Internacional  Amarelo         Andrés D'Alessandro
# 2        4608       1        Vitoria  Amarelo  Marcelo Machado dos Santos
# 3        4608       1        Vitoria  Amarelo                      Mansur
# 4        4607       1    Figueirense  Amarelo               Thiago Heleno
#
#    num_camisa     posicao minuto
# 0        28.0         NaN     66
# 1        10.0  Meio-campo     72
# 2        29.0         NaN     86
# 3         NaN    Zagueiro     10
# 4         4.0    Zagueiro     44

# %%
lista1 = df2['clube'].unique()

# %%
lista1 = sorted(lista1)
lista1
# Out:
# ['America-MG',
#  'Athletico-PR',
#  'Atletico-GO',
#  'Atletico-MG',
#  'Avai',
#  'Bahia',
#  'Botafogo-RJ',
#  'Bragantino',
#  'CSA',
#  'Ceara',
#  'Chapecoense',
#  'Corinthians',
#  'Coritiba',
#  'Criciuma',
#  'Cruzeiro',
#  'Cuiaba',
#  'Figueirense',
#  'Flamengo',
#  'Fluminense',
#  'Fortaleza',
#  'Goias',
#  'Gremio',
#  'Internacional',
#  'Joinville',
#  'Juventude',
#  'Palmeiras',
#  'Parana',
#  'Ponte Preta',
#  'Santa Cruz',
#  'Santos',
#  'Sao Paulo',
#  'Sport',
#  'Vasco',
#  'Vitoria']

# %%
mappings = {'America-MG' : 'América Mineiro',
 'Athletico-PR' : 'Athletico Paranaense',
 'Atletico-GO' : 'Atlético Goianiense',
 'Atletico-MG' :  'Atlético Mineiro',
 'Avai' : 'Avaí',
 'Botafogo-RJ' : 'Botafogo',
 'Ceara' :'Ceará',
 'Criciuma':"Criciúma",
 'Cuiaba':'Cuiabá',
 'Goias':'Goiás',
 'Gremio':'Grêmio',
 'Parana':'Paraná',
 'Sao Paulo' : 'São Paulo',
 'Vitoria':'Vitória'}
df2['clube'] = df2['clube'].replace(mappings)

# %%
df2.to_excel("DADOS\\campeonato-brasileiro-cartoes.xlsx",index=False)

# %% [markdown]
# -------------------

# %%
df3 = pd.read_csv("DADOS\\campeonato-brasileiro-estatisticas-full.csv")
df3.head()
# Out:
#    partida_id  rodata         clube  chutes  chutes_no_alvo posse_de_bola  \
# 0           1       1       Guarani       0               0           NaN
# 1           1       1         Vasco       0               0           NaN
# 2           2       1  Athletico-PR       0               0           NaN
# 3           2       1        Gremio       0               0           NaN
# 4           3       1      Flamengo       0               0           NaN
#
#    passes precisao_passes  faltas  cartao_amarelo  cartao_vermelho  \
# 0       0             NaN       0               0                0
# 1       0             NaN       0               0                0
# 2       0             NaN       0               0                0
# 3       0             NaN       0               0                0
# 4       0             NaN       0               0                0
#
#    impedimentos  escanteios
# 0             0           0
# 1             0           0
# 2             0           0
# ...

# %%
lista1 = df3['clube'].unique()
lista1 = sorted(lista1)
lista1
# Out:
# ['America-MG',
#  'America-RN',
#  'Athletico-PR',
#  'Atletico-GO',
#  'Atletico-MG',
#  'Avai',
#  'Bahia',
#  'Barueri',
#  'Botafogo-RJ',
#  'Bragantino',
#  'Brasiliense',
#  'CSA',
#  'Ceara',
#  'Chapecoense',
#  'Corinthians',
#  'Coritiba',
#  'Criciuma',
#  'Cruzeiro',
#  'Cuiaba',
#  'Figueirense',
#  'Flamengo',
#  'Fluminense',
#  'Fortaleza',
#  'Goias',
#  'Gremio',
#  'Gremio Prudente',
#  'Guarani',
#  'Internacional',
#  'Ipatinga',
#  'Joinville',
#  'Juventude',
#  'Nautico',
#  'Palmeiras',
#  'Parana',
#  'Paysandu',
#  'Ponte Preta',
#  'Portuguesa',
#  'Santa Cruz',
#  'Santo Andre',
#  'Santos',
#  'Sao Caetano',
#  'Sao Paulo',
#  'Sport',
#  'Vasco',
#  'Vitoria']

# %%
mappings = {'America-MG' : 'América Mineiro',
 'Athletico-PR':  'Athletico Paranaense',
 'Atletico-GO' : 'Atlético Goianiense',
 'Atletico-MG' :  'Atlético Mineiro',
 'Avai' :'Avaí',
 'Botafogo-RJ' :'Botafoto',
 'Ceara' : 'Ceará',
 'Criciuma' : 'Criciúma',
 'Cuiaba' : 'Cuiabá',
 'Goias' : 'Goiás',
 'Gremio':'Grêmio',
 'Gremio Prudente':'Grêmio Prudente',
 'Nautico' : 'Náutico',
 'Parana' : 'Paraná',
 'Santo Andre' : "Santo André",
 'Sao Caetano' : 'São Caetano',
 'Sao Paulo' : 'São Paulo',
 'Vitoria' : 'Vitória'}
df3['clube'] = df3['clube'].replace(mappings)

# %%
df3.to_excel("DADOS\\campeonato-brasileiro-estatisticas-full.xlsx",index=False)

# %% [markdown]
# ----------------

# %%
df4 = pd.read_csv("DADOS\\campeonato-brasileiro-full.csv")
df4.head()
# Out:
#    ID  rodata       data   hora       mandante    visitante formacao_mandante  \
# 0   1       1  29/3/2003  16:00        Guarani        Vasco               NaN
# 1   2       1  29/3/2003  16:00   Athletico-PR       Gremio               NaN
# 2   3       1  30/3/2003  16:00       Flamengo     Coritiba               NaN
# 3   4       1  30/3/2003  16:00          Goias     Paysandu               NaN
# 4   5       1  30/3/2003  16:00  Internacional  Ponte Preta               NaN
#
#   formacao_visitante tecnico_mandante tecnico_visitante      vencedor  \
# 0                NaN              NaN               NaN       Guarani
# 1                NaN              NaN               NaN  Athletico-PR
# 2                NaN              NaN               NaN             -
# 3                NaN              NaN               NaN             -
# 4                NaN              NaN               NaN             -
#
#                arena  mandante_Placar  visitante_Placar mandante_Estado  \
# ...

# %%
lista1 = df4['mandante'].unique()
lista1 = sorted(lista1)
lista1
# Out:
# ['America-MG',
#  'America-RN',
#  'Athletico-PR',
#  'Atletico-GO',
#  'Atletico-MG',
#  'Avai',
#  'Bahia',
#  'Barueri',
#  'Botafogo-RJ',
#  'Bragantino',
#  'Brasiliense',
#  'CSA',
#  'Ceara',
#  'Chapecoense',
#  'Corinthians',
#  'Coritiba',
#  'Criciuma',
#  'Cruzeiro',
#  'Cuiaba',
#  'Figueirense',
#  'Flamengo',
#  'Fluminense',
#  'Fortaleza',
#  'Goias',
#  'Gremio',
#  'Gremio Prudente',
#  'Guarani',
#  'Internacional',
#  'Ipatinga',
#  'Joinville',
#  'Juventude',
#  'Nautico',
#  'Palmeiras',
#  'Parana',
#  'Paysandu',
#  'Ponte Preta',
#  'Portuguesa',
#  'Santa Cruz',
#  'Santo Andre',
#  'Santos',
#  'Sao Caetano',
#  'Sao Paulo',
#  'Sport',
#  'Vasco',
#  'Vitoria']

# %%
mappings = {'America-MG':'América Mineiro',
 'Athletico-PR':'Athletico Paranaense',
 'Atletico-GO': 'Atlético Goianiense',
 'Atletico-MG': 'Atlético Mineiro',
 'Avai':'Avaí',
 'Botafogo-RJ':'Botafogo',
 'Ceara':'Ceará',
 'Criciuma':'Criciúma',
 'Cuiaba':'Cuiabá',
 'Goias':'Goiás',
 'Gremio':'Grêmio',
 'Gremio Prudente':'Grêmio Prudente',
 'Nautico':'Náutico',
 'Parana':'Paraná',
 'Santo Andre':'Santo André',
 'Sao Caetano': 'São Caetano',
 'Sao Paulo':'São Paulo',
 'Vitoria':'Vitória'}
df4['mandante'] = df4['mandante'].replace(mappings)
df4['visitante'] = df4['visitante'].replace(mappings)
df4['vencedor'] = df4['vencedor'].replace(mappings)

# %%
df4.to_excel("DADOS\\campeonato-brasileiro-full.xlsx",index=False)
